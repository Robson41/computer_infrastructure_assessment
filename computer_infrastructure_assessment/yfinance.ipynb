# %% [markdown]
# # yfinance notebook
#
# This notebook was repaired to valid JSON and contains a small smoke-test cell below. If you have a local environment with the dependencies installed, run the Python cell to verify `yfinance` and core libraries import correctly.

# %%
# Simple smoke test for yfinance and core libs
import importlib

modules = ['yfinance', 'numpy', 'pandas']
for m in modules:
    try:
        mod = importlib.import_module(m)
        print(f"{m} imported, version=", getattr(mod, '__version__', 'unknown'))
    except Exception as e:
        print(f"Failed to import {m}: {e}")
